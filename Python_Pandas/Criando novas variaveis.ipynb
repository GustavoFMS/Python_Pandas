# %% [markdown]
# # Relatório de Análise

# %% [markdown]
# ## Criando Novas Variaveis

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel.csv', sep= ';')

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento         Cachambi        2      0       0    50
# 6       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 7       Casa de Condomínio            Ramos        2      2       0    65
# 8  Conjunto Comercial/Sala           Centro        0      3       0   695
# 9              Apartamento           Grajaú        2      1       0    70
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         0.0     0.0
# 2   5200.0      4020.0  1111.0
# 3    800.0       390.0    20.0
# 4    800.0       230.0     0.0
# 5   1300.0       301.0    17.0
# 6  22000.0         0.0     0.0
# 7   1000.0         0.0     0.0
# 8  35000.0     19193.0  3030.0
# 9   1500.0       642.0    74.0

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento         Cachambi        2      0       0    50
# 6       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 7       Casa de Condomínio            Ramos        2      2       0    65
# 8  Conjunto Comercial/Sala           Centro        0      3       0   695
# 9              Apartamento           Grajaú        2      1       0    70
#
#      Valor  Condominio    IPTU  Valor Bruto
# 0   1700.0       500.0    60.0       2260.0
# 1   7000.0         0.0     0.0       7000.0
# 2   5200.0      4020.0  1111.0      10331.0
# 3    800.0       390.0    20.0       1210.0
# 4    800.0       230.0     0.0       1030.0
# 5   1300.0       301.0    17.0       1618.0
# 6  22000.0         0.0     0.0      22000.0
# 7   1000.0         0.0     0.0       1000.0
# 8  35000.0     19193.0  3030.0      57223.0
# 9   1500.0       642.0    74.0       2216.0

# %%
dados['Valor m2'] = dados['Valor'] / dados['Area']
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento         Cachambi        2      0       0    50
# 6       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 7       Casa de Condomínio            Ramos        2      2       0    65
# 8  Conjunto Comercial/Sala           Centro        0      3       0   695
# 9              Apartamento           Grajaú        2      1       0    70
#
#      Valor  Condominio    IPTU  Valor Bruto   Valor m2
# 0   1700.0       500.0    60.0       2260.0  42.500000
# 1   7000.0         0.0     0.0       7000.0  70.000000
# 2   5200.0      4020.0  1111.0      10331.0  34.666667
# 3    800.0       390.0    20.0       1210.0  53.333333
# 4    800.0       230.0     0.0       1030.0  16.666667
# 5   1300.0       301.0    17.0       1618.0  26.000000
# 6  22000.0         0.0     0.0      22000.0  29.333333
# 7   1000.0         0.0     0.0       1000.0  15.384615
# 8  35000.0     19193.0  3030.0      57223.0  50.359712
# 9   1500.0       642.0    74.0       2216.0  21.428571

# %%
dados['Valor m2'] = dados['Valor m2'].round(2)
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento         Cachambi        2      0       0    50
# 6       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 7       Casa de Condomínio            Ramos        2      2       0    65
# 8  Conjunto Comercial/Sala           Centro        0      3       0   695
# 9              Apartamento           Grajaú        2      1       0    70
#
#      Valor  Condominio    IPTU  Valor Bruto  Valor m2
# 0   1700.0       500.0    60.0       2260.0     42.50
# 1   7000.0         0.0     0.0       7000.0     70.00
# 2   5200.0      4020.0  1111.0      10331.0     34.67
# 3    800.0       390.0    20.0       1210.0     53.33
# 4    800.0       230.0     0.0       1030.0     16.67
# 5   1300.0       301.0    17.0       1618.0     26.00
# 6  22000.0         0.0     0.0      22000.0     29.33
# 7   1000.0         0.0     0.0       1000.0     15.38
# 8  35000.0     19193.0  3030.0      57223.0     50.36
# 9   1500.0       642.0    74.0       2216.0     21.43

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto'] / dados['Area']).round(2)
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento         Cachambi        2      0       0    50
# 6       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 7       Casa de Condomínio            Ramos        2      2       0    65
# 8  Conjunto Comercial/Sala           Centro        0      3       0   695
# 9              Apartamento           Grajaú        2      1       0    70
#
#      Valor  Condominio    IPTU  Valor Bruto  Valor m2  Valor Bruto m2
# 0   1700.0       500.0    60.0       2260.0     42.50           56.50
# 1   7000.0         0.0     0.0       7000.0     70.00           70.00
# 2   5200.0      4020.0  1111.0      10331.0     34.67           68.87
# 3    800.0       390.0    20.0       1210.0     53.33           80.67
# 4    800.0       230.0     0.0       1030.0     16.67           21.46
# 5   1300.0       301.0    17.0       1618.0     26.00           32.36
# 6  22000.0         0.0     0.0      22000.0     29.33           29.33
# 7   1000.0         0.0     0.0       1000.0     15.38           15.38
# 8  35000.0     19193.0  3030.0      57223.0     50.36           82.34
# 9   1500.0       642.0    74.0       2216.0     21.43           31.66

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32193                Quitinete                Centro        0      0       0
# 32194              Apartamento           Jacarepaguá        3      1       2
# 32195              Apartamento  São Francisco Xavier        2      1       0
# 32196              Apartamento                Leblon        2      0       0
# 32197  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU  Valor Bruto  Valor m2  \
# 0        40  1700.0       500.0    60.0       2260.0     42.50
# 1       100  7000.0         0.0     0.0       7000.0     70.00
# 2       150  5200.0      4020.0  1111.0      10331.0     34.67
# 3        15   800.0       390.0    20.0       1210.0     53.33
# 4        48   800.0       230.0     0.0       1030.0     16.67
# ...     ...     ...         ...     ...          ...       ...
# 32193    27   800.0       350.0    25.0       1175.0     29.63
# 32194    78  1800.0       800.0    40.0       2640.0     23.08
# 32195    48  1400.0       509.0    37.0       1946.0     29.17
# 32196    70  3000.0       760.0     0.0       3760.0     42.86
# 32197   250  6500.0      4206.0  1109.0      11815.0     26.00
#
#        Valor Bruto m2 Tipo Agregado
# 0               56.50   Apartamento
# 1               70.00          Casa
# 2               68.87   Apartamento
# 3               80.67   Apartamento
# 4               21.46   Apartamento
# ...               ...           ...
# 32193           43.52   Apartamento
# 32194           33.85   Apartamento
# 32195           40.54   Apartamento
# 32196           53.71   Apartamento
# 32197           47.26   Apartamento
#
# [32198 rows x 13 columns]

# %% [markdown]
# ## Excluindo Variáveis do dataFrame

# %%
del dados['Valor Bruto']

# %%
dados.pop('Valor Bruto m2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Valor Bruto m2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 dados.pop('Valor Bruto m2')
#       2 dados
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5685, in DataFrame.pop(self, item)
#    5644 def pop(self, item: Hashable) -> Series:
#    5645     """
#    5646     Return item and drop from frame. Raise KeyError if not found.
#    5647
#    (...)
#    5683     3  monkey        NaN
#    5684     """
# -> 5685     return super().pop(item=item)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:923, in NDFrame.pop(self, item)
#     922 def pop(self, item: Hashable) -> Series | Any:
# --> 923     result = self[item]
#     924     del self[item]
#     926     return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Valor Bruto m2'

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32193                Quitinete                Centro        0      0       0
# 32194              Apartamento           Jacarepaguá        3      1       2
# 32195              Apartamento  São Francisco Xavier        2      1       0
# 32196              Apartamento                Leblon        2      0       0
# 32197  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0        40  1700.0       500.0    60.0     42.50   Apartamento
# 1       100  7000.0         0.0     0.0     70.00          Casa
# 2       150  5200.0      4020.0  1111.0     34.67   Apartamento
# 3        15   800.0       390.0    20.0     53.33   Apartamento
# 4        48   800.0       230.0     0.0     16.67   Apartamento
# ...     ...     ...         ...     ...       ...           ...
# 32193    27   800.0       350.0    25.0     29.63   Apartamento
# 32194    78  1800.0       800.0    40.0     23.08   Apartamento
# 32195    48  1400.0       509.0    37.0     29.17   Apartamento
# 32196    70  3000.0       760.0     0.0     42.86   Apartamento
# 32197   250  6500.0      4206.0  1109.0     26.00   Apartamento
#
# [32198 rows x 11 columns]

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32193                Quitinete                Centro        0      0       0
# 32194              Apartamento           Jacarepaguá        3      1       2
# 32195              Apartamento  São Francisco Xavier        2      1       0
# 32196              Apartamento                Leblon        2      0       0
# 32197  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0        40  1700.0       500.0    60.0     42.50   Apartamento
# 1       100  7000.0         0.0     0.0     70.00          Casa
# 2       150  5200.0      4020.0  1111.0     34.67   Apartamento
# 3        15   800.0       390.0    20.0     53.33   Apartamento
# 4        48   800.0       230.0     0.0     16.67   Apartamento
# ...     ...     ...         ...     ...       ...           ...
# 32193    27   800.0       350.0    25.0     29.63   Apartamento
# 32194    78  1800.0       800.0    40.0     23.08   Apartamento
# 32195    48  1400.0       509.0    37.0     29.17   Apartamento
# 32196    70  3000.0       760.0     0.0     42.86   Apartamento
# 32197   250  6500.0      4206.0  1109.0     26.00   Apartamento
#
# [32198 rows x 11 columns]

# %%
dados.to_csv('dados/aluguel.csv', sep=';',index=False)
